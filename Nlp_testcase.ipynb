# %% [markdown]
# <a href="https://colab.research.google.com/github/pavan-07/Stock_prediction/blob/master/Nlp_testcase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install Necessary Packages.
# !pip install python-docx
# !pip install nltk

# %%
# @title Necessary imports and globals.
#load files
import nltk
import docx

# %%
# @title Importing and loading a Dataset.
#using colab local file importing..
from google.colab import files
files.upload()    #from the local drive
# Out:
#      <input type="file" id="files-563ab20a-bf4c-47ee-b21e-b74138664a5e" name="files[]" multiple disabled />
#      <output id="result-563ab20a-bf4c-47ee-b21e-b74138664a5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BRD_Sample-1.docx to BRD_Sample-1.docx
# ...

# %%
document = docx.Document('BRD_Sample-1.docx')
tables = document.tables
for table in tables:
    for row in table.rows:
        for cell in row.cells:
            for paragraph in cell.paragraphs:
                print(paragraph.text)                    #Storing the data in a txt file
# Out:
# Project: NLP Based Requirements to Test case Creation
#
#
# Document File Name
# BRD Sample
# Version
# 1.0
# Version Date
# 05-Oct-2018
# Author
# UTO- RnD Team
# Business Requirement Details
# Business Requirement Details
# Business Requirement Details
# Requirement ID
# Requirement Description
# Functionality / TC
# Req_001
# User should be able to login after providing the user id and password; and pressing the login button of the application.
#
# Req_002
# User Should provide user id and password. Press the Login Button before user can login to application successfully.
#
# Req_003
# Upon successful login, user clicks on the transaction tab; and user should see the transaction tab
#
# Req_004
# On Transaction tab, User should fill out fields like Customer Name, Age, Employment Status, Email id and Account Number; and click on Save button; application should save the values of Customer Name, Age, Employment Status, Email id and Account Number.
#
# Req_005
# ...
